# %%
import numpy as np
import pandas as pd

# %%
movie = pd.read_csv('movie.csv')

# %%
# returns first five columns 
movie.head()
# Out:
#                                         title    year  color content_rating  \
# 0                                      Avatar  2009.0  Color          PG-13
# 1    Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# 2                                     Spectre  2015.0  Color          PG-13
# 3                       The Dark Knight Rises  2012.0  Color          PG-13
# 4  Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
#
#    duration      director_name  director_fb           actor1  actor1_fb  \
# 0     178.0      James Cameron          0.0      CCH Pounder     1000.0
# 1     169.0     Gore Verbinski        563.0      Johnny Depp    40000.0
# 2     148.0         Sam Mendes          0.0  Christoph Waltz    11000.0
# 3     164.0  Christopher Nolan      22000.0        Tom Hardy    27000.0
# 4       NaN        Doug Walker        131.0      Doug Walker      131.0
#
#              actor2    ...      actor3_fb        gross  \
# ...

# %%
# checking out count and mean std min ect and counts returns non null value
movie.describe()
# Out:
#               year     duration   director_fb      actor1_fb      actor2_fb  \
# count  4810.000000  4901.000000   4814.000000    4909.000000    4903.000000
# mean   2002.447609   107.090798    691.014541    6494.488491    1621.923516
# std      12.453977    25.286015   2832.954125   15106.986884    4011.299523
# min    1916.000000     7.000000      0.000000       0.000000       0.000000
# 25%    1999.000000    93.000000      7.000000     607.000000     277.000000
# 50%    2005.000000   103.000000     48.000000     982.000000     593.000000
# 75%    2011.000000   118.000000    189.750000   11000.000000     912.000000
# max    2016.000000   511.000000  23000.000000  640000.000000  137000.000000
#
#           actor3_fb         gross  num_reviews  num_voted_users        budget  \
# count   4893.000000  4.054000e+03  4867.000000     4.916000e+03  4.432000e+03
# mean     631.276313  4.764451e+07   137.988905     8.264492e+04  3.654749e+07
# ...

# %%
# 4916 rows
len(movie)
# Out:
# 4916

# %%
# is there null value count and see that title,genres, num_voted_users and imdb_score has no missing value
# and NAN is considered as float
movie.isnull().sum()
# Out:
# title                0
# year               106
# color               19
# content_rating     300
# duration            15
# director_name      102
# director_fb        102
# actor1               7
# actor1_fb            7
# actor2              13
# actor2_fb           13
# actor3              23
# actor3_fb           23
# gross              862
# genres               0
# num_reviews         49
# num_voted_users      0
# plot_keywords      152
# language            12
# country              5
# budget             484
# imdb_score           0
# dtype: int64

# %%
# checking columns 
movie.columns
# Out:
# Index(['title', 'year', 'color', 'content_rating', 'duration', 'director_name',
#        'director_fb', 'actor1', 'actor1_fb', 'actor2', 'actor2_fb', 'actor3',
#        'actor3_fb', 'gross', 'genres', 'num_reviews', 'num_voted_users',
#        'plot_keywords', 'language', 'country', 'budget', 'imdb_score'],
#       dtype='object')

# %%
# getting series for movie year and it says float 
movie.year.head()
# Out:
# 0    2009.0
# 1    2007.0
# 2    2015.0
# 3    2012.0
# 4       NaN
# Name: year, dtype: float64

# %%
# changing year to datetime format and Nan becomes NAT for datetime
movie['year'] = pd.to_datetime(movie['year'])

# %%
movie.head()
# Out:
#                                         title                          year  \
# 0                                      Avatar 1970-01-01 00:00:00.000002009
# 1    Pirates of the Caribbean: At World's End 1970-01-01 00:00:00.000002007
# 2                                     Spectre 1970-01-01 00:00:00.000002015
# 3                       The Dark Knight Rises 1970-01-01 00:00:00.000002012
# 4  Star Wars: Episode VII - The Force Awakens                           NaT
#
#    color content_rating  duration      director_name  director_fb  \
# 0  Color          PG-13     178.0      James Cameron          0.0
# 1  Color          PG-13     169.0     Gore Verbinski        563.0
# 2  Color          PG-13     148.0         Sam Mendes          0.0
# 3  Color          PG-13     164.0  Christopher Nolan      22000.0
# 4    NaN            NaN       NaN        Doug Walker        131.0
#
#             actor1  actor1_fb            actor2    ...      actor3_fb  \
# ...
